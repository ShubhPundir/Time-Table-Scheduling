# %%
from NewBase import course_list, faculty_list, section_list
import random
import sys
sys.setrecursionlimit(12000)

# %%
## Time table operations
def display_timetable(temp):
    for row,cols in temp.timetable.items():
        print(row,':',cols)

def get_faculty(section,course):
    print('Section:',section.section_name)
    print('Course:',course.course_name)
    print('Faculty name:',section.courses[course].faculty_name)
    return section.courses[course] ## faculty object
        

def faculty_insert(faculty,day,position,section):
    faculty.timetable[day][position] = section.section_name
    print(f"Section {section.section_name} successfully scheduled at Day {day} Position {position}.")
    
def section_insert(section,day,position,course):
    section.timetable[day][position] = course.course_code    
    print(f"Class {course.course_name} successfully scheduled at Day {day} Position {position}.")
    
def single_insert_check(section,day,position,course):
    position = position - 1
    faculty = section.courses[course] ## get faculty object
    print('FACULTY:',faculty.faculty_name)
    if course.course_code in section.timetable[day]:
        print(f"Class {course.course_name} is already scheduled on Day {day}. Finding a new day.")
        new_day = random.choice(list(section.timetable.keys()))
        print(f"Trying a new day: {new_day}")
        single_insert_check(section, new_day, position + 1, course)
        return
    if section.timetable[day][position] == 0 and faculty.timetable[day][position] == 0:
        # slot free for both faculty and section
        section_insert(section, day, position, course)
        faculty_insert(faculty, day, position, section)
        print('----'*50)
        return
    else:
        # case of clash
        print(f"Class slot at Day {day} Position {position} is occupied. Finding a new position.")
        new_position = random.randint(1, 6)
        print(f"Trying a new position: {new_position}")
        single_insert_check(section, day, new_position, course)
        
def double_insert_check(section,day,position,course):
    position = position - 1
    faculty = section.courses[course] ## get faculty object
    print('FACULTY:',faculty.faculty_name)

    if section.timetable[day][position] == 0 and section.timetable[day][position+1] == 0 and faculty.timetable[day][position] == 0:
        # slot free for both faculty and section
        section_insert(section, day, position, course)
#         print('BAZZZZZINGA')
        section_insert(section, day, position+1, course)
        print()
        faculty_insert(faculty, day, position, section)
#         print('BAZZZZZINGA')
        faculty_insert(faculty, day, position+1, section)
        print('----'*50)
        return
    else:
        # case of clash
        print(f"Class slot at Day {day} Position {position} is occupied. Finding a new position.")
        new_position = random.randint(1, 5)
        print(f"Trying a new position: {new_position}")
        double_insert_check(section, day, new_position, course)

    
def get_major(section):
    d = section.courses
    return list(d.keys())[-1] # returns an object

# %%
## Default courses fill up

default_courses = course_list[0:4]
default_courses
# Out:
# [<NewBase.Course at 0x200e84298d0>,
#  <NewBase.Course at 0x200e8429010>,
#  <NewBase.Course at 0x200e84290d0>,
#  <NewBase.Course at 0x200e8429110>]

# %% [markdown]
# ## Default courses laboratory classes fill up

# %%
days = ['Monday','Tuesday','Wednesday','Thursday','Friday']
for i in default_courses:
    for j in section_list:
        rand_day = random.sample(days, i.course_labs) # random day from Monday to Friday
        for d in rand_day:
            slot = random.randint(1, 5) #  random slot from 1 to 5 --> as it's a 2 hour continuous class
            double_insert_check(section=j, day=d, position=slot, course=i)
# Out:
# FACULTY: Yogita
# Class Computer Networks successfully scheduled at Day Wednesday Position 1.
# Class Computer Networks successfully scheduled at Day Wednesday Position 2.
#
# Section A successfully scheduled at Day Wednesday Position 1.
# Section A successfully scheduled at Day Wednesday Position 2.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Neeti
# Class Computer Networks successfully scheduled at Day Monday Position 2.
# Class Computer Networks successfully scheduled at Day Monday Position 3.
#
# Section B successfully scheduled at Day Monday Position 2.
# Section B successfully scheduled at Day Monday Position 3.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Yogita
# Class Computer Networks successfully scheduled at Day Tuesday Position 4.
# Class Computer Networks successfully scheduled at Day Tuesday Position 5.
#
# Section C successfully scheduled at Day Tuesday Position 4.
# Section C successfully scheduled at Day Tuesday Position 5.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Neetu
# Class Computer Networks successfully scheduled at Day Wednesday Position 0.
# Class Computer Networks successfully scheduled at Day Wednesday Position 1.
#
# Section D successfully scheduled at Day Wednesday Position 0.
# Section D successfully scheduled at Day Wednesday Position 1.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Mehak
# Class Computer Networks successfully scheduled at Day Monday Position 4.
# Class Computer Networks successfully scheduled at Day Monday Position 5.
#
# Section E successfully scheduled at Day Monday Position 4.
# Section E successfully scheduled at Day Monday Position 5.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Anuradha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Anuradha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Anuradha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Anuradha
# Class Data Structures successfully scheduled at Day Wednesday Position 4.
# Class Data Structures successfully scheduled at Day Wednesday Position 5.
#
# Section A successfully scheduled at Day Wednesday Position 4.
# Section A successfully scheduled at Day Wednesday Position 5.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Shilpa
# Class Data Structures successfully scheduled at Day Friday Position 4.
# Class Data Structures successfully scheduled at Day Friday Position 5.
#
# Section B successfully scheduled at Day Friday Position 4.
# Section B successfully scheduled at Day Friday Position 5.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Anshul
# Class Data Structures successfully scheduled at Day Wednesday Position 3.
# Class Data Structures successfully scheduled at Day Wednesday Position 4.
#
# Section C successfully scheduled at Day Wednesday Position 3.
# Section C successfully scheduled at Day Wednesday Position 4.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Shaveta
# Class Data Structures successfully scheduled at Day Friday Position 2.
# Class Data Structures successfully scheduled at Day Friday Position 3.
#
# Section D successfully scheduled at Day Friday Position 2.
# Section D successfully scheduled at Day Friday Position 3.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Neetu
# Class Data Structures successfully scheduled at Day Tuesday Position 2.
# Class Data Structures successfully scheduled at Day Tuesday Position 3.
#
# Section E successfully scheduled at Day Tuesday Position 2.
# Section E successfully scheduled at Day Tuesday Position 3.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Pooja
# Class Digital Electronics successfully scheduled at Day Thursday Position 3.
# Class Digital Electronics successfully scheduled at Day Thursday Position 4.
#
# Section A successfully scheduled at Day Thursday Position 3.
# Section A successfully scheduled at Day Thursday Position 4.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Arjun
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Arjun
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Arjun
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Arjun
# Class Digital Electronics successfully scheduled at Day Monday Position 4.
# Class Digital Electronics successfully scheduled at Day Monday Position 5.
#
# Section B successfully scheduled at Day Monday Position 4.
# Section B successfully scheduled at Day Monday Position 5.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Sharda
# Class Digital Electronics successfully scheduled at Day Tuesday Position 2.
# Class Digital Electronics successfully scheduled at Day Tuesday Position 3.
#
# Section C successfully scheduled at Day Tuesday Position 2.
# Section C successfully scheduled at Day Tuesday Position 3.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Anjali
# Class Digital Electronics successfully scheduled at Day Monday Position 4.
# Class Digital Electronics successfully scheduled at Day Monday Position 5.
#
# Section D successfully scheduled at Day Monday Position 4.
# Section D successfully scheduled at Day Monday Position 5.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Vandana
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Vandana
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Vandana
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Vandana
# Class Digital Electronics successfully scheduled at Day Monday Position 0.
# Class Digital Electronics successfully scheduled at Day Monday Position 1.
#
# Section E successfully scheduled at Day Monday Position 0.
# Section E successfully scheduled at Day Monday Position 1.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
for sec in section_list:
    print('Section',sec.section_name)
    display_timetable(sec)
    print('----'*20)
# Out:
# Section A
# Monday : [0, 0, 0, 0, 0, 0]
# Tuesday : [0, 0, 0, 0, 0, 0]
# Wednesday : [0, 101, 101, 0, 102, 102]
# Thursday : [0, 0, 0, 104, 104, 0]
# Friday : [0, 0, 0, 0, 0, 0]
# --------------------------------------------------------------------------------
# Section B
# Monday : [0, 0, 101, 101, 104, 104]
# Tuesday : [0, 0, 0, 0, 0, 0]
# Wednesday : [0, 0, 0, 0, 0, 0]
# Thursday : [0, 0, 0, 0, 0, 0]
# Friday : [0, 0, 0, 0, 102, 102]
# --------------------------------------------------------------------------------
# Section C
# Monday : [0, 0, 0, 0, 0, 0]
# Tuesday : [0, 0, 104, 104, 101, 101]
# Wednesday : [0, 0, 0, 102, 102, 0]
# Thursday : [0, 0, 0, 0, 0, 0]
# Friday : [0, 0, 0, 0, 0, 0]
# --------------------------------------------------------------------------------
# Section D
# Monday : [0, 0, 0, 0, 104, 104]
# Tuesday : [0, 0, 0, 0, 0, 0]
# Wednesday : [101, 101, 0, 0, 0, 0]
# Thursday : [0, 0, 0, 0, 0, 0]
# Friday : [0, 0, 102, 102, 0, 0]
# --------------------------------------------------------------------------------
# Section E
# Monday : [104, 104, 0, 0, 101, 101]
# Tuesday : [0, 0, 102, 102, 0, 0]
# Wednesday : [0, 0, 0, 0, 0, 0]
# Thursday : [0, 0, 0, 0, 0, 0]
# Friday : [0, 0, 0, 0, 0, 0]
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Major course laboratory class fill up

# %%
for sec in section_list:
    major = get_major(sec)
    rand_day = random.sample(days, major.course_labs) # random day from Monday to Friday
    for d in rand_day:
        slot = random.randint(1, 5) #  random slot from 1 to 6
        double_insert_check(section=sec, day=d, position=slot, course=major)
# Out:
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# ...
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[6], line 6
#       4 for d in rand_day:
#       5     slot = random.randint(1, 5) #  random slot from 1 to 6
# ----> 6     double_insert_check(section=sec, day=d, position=slot, course=major)
#
# Cell In[2], line 65, in double_insert_check(section, day, position, course)
#      63 new_position = random.randint(1, 5)
#      64 print(f"Trying a new position: {new_position}")
# ---> 65 double_insert_check(section, day, new_position, course)
#
# Cell In[2], line 65, in double_insert_check(section, day, position, course)
#      63 new_position = random.randint(1, 5)
#      64 print(f"Trying a new position: {new_position}")
# ---> 65 double_insert_check(section, day, new_position, course)
#
#     [... skipping similar frames: double_insert_check at line 65 (11967 times)]
#
# Cell In[2], line 65, in double_insert_check(section, day, position, course)
#      63 new_position = random.randint(1, 5)
#      64 print(f"Trying a new position: {new_position}")
# ---> 65 double_insert_check(section, day, new_position, course)
#
# Cell In[2], line 63, in double_insert_check(section, day, position, course)
#      60 else:
#      61     # case of clash
#      62     print(f"Class slot at Day {day} Position {position} is occupied. Finding a new position.")
# ---> 63     new_position = random.randint(1, 5)
#      64     print(f"Trying a new position: {new_position}")
#      65     double_insert_check(section, day, new_position, course)
#
# File ~\anaconda3\Lib\random.py:362, in Random.randint(self, a, b)
#     358 def randint(self, a, b):
#     359     """Return random integer in range [a, b], including both end points.
#     360     """
# --> 362     return self.randrange(a, b+1)
#
# File ~\anaconda3\Lib\random.py:344, in Random.randrange(self, start, stop, step)
#     342 if istep == 1:
#     343     if width > 0:
# --> 344         return istart + self._randbelow(width)
#     345     raise ValueError("empty range for randrange() (%d, %d, %d)" % (istart, istop, width))
#     347 # Non-unit step argument supplied.
#
# File ~\anaconda3\Lib\random.py:239, in Random._randbelow_with_getrandbits(self, n)
#     236 "Return a random int in the range [0,n).  Defined for n > 0."
#     238 getrandbits = self.getrandbits
# --> 239 k = n.bit_length()  # don't use (n-1) here because n can be 1
#     240 r = getrandbits(k)  # 0 <= r < 2**k
#     241 while r >= n:
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
for sec in section_list:
    print('Section',sec.section_name)
    display_timetable(sec)
    print('----'*20)
# Out:
# Section A
# Monday : [0, 0, 0, 0, 0, 0]
# Tuesday : [0, 0, 0, 0, 0, 0]
# Wednesday : [0, 101, 101, 0, 102, 102]
# Thursday : [0, 0, 0, 104, 104, 0]
# Friday : [0, 0, 0, 0, 0, 0]
# --------------------------------------------------------------------------------
# Section B
# Monday : [0, 0, 101, 101, 104, 104]
# Tuesday : [0, 0, 0, 0, 0, 0]
# Wednesday : [0, 0, 0, 0, 0, 0]
# Thursday : [0, 0, 0, 0, 0, 0]
# Friday : [0, 0, 0, 0, 102, 102]
# --------------------------------------------------------------------------------
# Section C
# Monday : [0, 0, 0, 0, 0, 0]
# Tuesday : [0, 0, 104, 104, 101, 101]
# Wednesday : [0, 0, 0, 102, 102, 0]
# Thursday : [0, 0, 0, 0, 0, 0]
# Friday : [0, 0, 0, 0, 0, 0]
# --------------------------------------------------------------------------------
# Section D
# Monday : [0, 0, 0, 0, 104, 104]
# Tuesday : [0, 0, 0, 0, 0, 0]
# Wednesday : [101, 101, 0, 0, 0, 0]
# Thursday : [0, 0, 0, 0, 0, 0]
# Friday : [0, 0, 102, 102, 0, 0]
# --------------------------------------------------------------------------------
# Section E
# Monday : [104, 104, 0, 0, 101, 101]
# Tuesday : [0, 0, 102, 102, 0, 0]
# Wednesday : [0, 0, 0, 0, 0, 0]
# Thursday : [0, 0, 0, 0, 0, 0]
# Friday : [0, 0, 0, 0, 0, 0]
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Default courses lectures fill up

# %%
days = ['Monday','Tuesday','Wednesday','Thursday','Friday']

for i in default_courses:
    for j in section_list:
        rand_day = random.sample(days, i.course_lectures) # random day from Monday to Friday
        for d in rand_day:
            slot = random.randint(1, 6) #  random slot from 1 to 6
            single_insert_check(section=j, day=d, position=slot, course=i)
# Out:
# FACULTY: Yogita
# Class Computer Networks successfully scheduled at Day Tuesday Position 2.
# Section A successfully scheduled at Day Tuesday Position 2.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Yogita
# Class Computer Networks successfully scheduled at Day Thursday Position 5.
# Section A successfully scheduled at Day Thursday Position 5.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Yogita
# Class Computer Networks successfully scheduled at Day Friday Position 0.
# Section A successfully scheduled at Day Friday Position 0.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Neeti
# Class Computer Networks successfully scheduled at Day Friday Position 0.
# Section B successfully scheduled at Day Friday Position 0.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Neeti
# Class Computer Networks successfully scheduled at Day Wednesday Position 3.
# Section B successfully scheduled at Day Wednesday Position 3.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Neeti
# Class Computer Networks successfully scheduled at Day Thursday Position 2.
# Section B successfully scheduled at Day Thursday Position 2.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Yogita
# Class Computer Networks successfully scheduled at Day Thursday Position 0.
# Section C successfully scheduled at Day Thursday Position 0.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Yogita
# Class Computer Networks successfully scheduled at Day Wednesday Position 5.
# Section C successfully scheduled at Day Wednesday Position 5.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Yogita
# Class slot at Day Friday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Yogita
# Class Computer Networks successfully scheduled at Day Friday Position 1.
# Section C successfully scheduled at Day Friday Position 1.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Neetu
# Class slot at Day Tuesday Position 3 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Neetu
# Class Computer Networks successfully scheduled at Day Tuesday Position 5.
# Section D successfully scheduled at Day Tuesday Position 5.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Neetu
# Class Computer Networks successfully scheduled at Day Friday Position 1.
# Section D successfully scheduled at Day Friday Position 1.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Neetu
# Class Computer Networks successfully scheduled at Day Thursday Position 2.
# Section D successfully scheduled at Day Thursday Position 2.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Mehak
# Class Computer Networks successfully scheduled at Day Friday Position 0.
# Section E successfully scheduled at Day Friday Position 0.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Mehak
# Class Computer Networks successfully scheduled at Day Thursday Position 1.
# Section E successfully scheduled at Day Thursday Position 1.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Mehak
# Class slot at Day Tuesday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Mehak
# Class Computer Networks successfully scheduled at Day Tuesday Position 1.
# Section E successfully scheduled at Day Tuesday Position 1.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Anuradha
# Class slot at Day Thursday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Anuradha
# Class Data Structures successfully scheduled at Day Thursday Position 1.
# Section A successfully scheduled at Day Thursday Position 1.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Anuradha
# Class Data Structures successfully scheduled at Day Monday Position 0.
# Section A successfully scheduled at Day Monday Position 0.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Anuradha
# Class slot at Day Friday Position 0 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Anuradha
# Class slot at Day Friday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Anuradha
# Class Data Structures successfully scheduled at Day Friday Position 3.
# Section A successfully scheduled at Day Friday Position 3.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Shilpa
# Class Data Structures successfully scheduled at Day Wednesday Position 1.
# Section B successfully scheduled at Day Wednesday Position 1.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Shilpa
# Class Data Structures successfully scheduled at Day Tuesday Position 3.
# Section B successfully scheduled at Day Tuesday Position 3.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Shilpa
# Class Data Structures successfully scheduled at Day Thursday Position 0.
# Section B successfully scheduled at Day Thursday Position 0.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Anshul
# Class Data Structures successfully scheduled at Day Thursday Position 2.
# Section C successfully scheduled at Day Thursday Position 2.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Anshul
# Class Data Structures successfully scheduled at Day Monday Position 4.
# Section C successfully scheduled at Day Monday Position 4.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Anshul
# Class Data Structures successfully scheduled at Day Friday Position 2.
# Section C successfully scheduled at Day Friday Position 2.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Shaveta
# Class Data Structures successfully scheduled at Day Monday Position 0.
# Section D successfully scheduled at Day Monday Position 0.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Shaveta
# Class slot at Day Thursday Position 2 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class Data Structures successfully scheduled at Day Thursday Position 5.
# Section D successfully scheduled at Day Thursday Position 5.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Shaveta
# Class Data Structures is already scheduled on Day Friday. Finding a new day.
# Trying a new day: Monday
# FACULTY: Shaveta
# Class Data Structures is already scheduled on Day Monday. Finding a new day.
# Trying a new day: Thursday
# FACULTY: Shaveta
# Class Data Structures is already scheduled on Day Thursday. Finding a new day.
# Trying a new day: Tuesday
# FACULTY: Shaveta
# Class Data Structures successfully scheduled at Day Tuesday Position 0.
# Section D successfully scheduled at Day Tuesday Position 0.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Neetu
# Class Data Structures is already scheduled on Day Tuesday. Finding a new day.
# Trying a new day: Wednesday
# FACULTY: Neetu
# Class Data Structures successfully scheduled at Day Wednesday Position 3.
# Section E successfully scheduled at Day Wednesday Position 3.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Neetu
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Neetu
# Class Data Structures successfully scheduled at Day Monday Position 3.
# Section E successfully scheduled at Day Monday Position 3.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Neetu
# Class slot at Day Thursday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Neetu
# Class Data Structures successfully scheduled at Day Thursday Position 0.
# Section E successfully scheduled at Day Thursday Position 0.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Neha
# Class Discrete Mathematics successfully scheduled at Day Tuesday Position 1.
# Section A successfully scheduled at Day Tuesday Position 1.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Neha
# Class Discrete Mathematics successfully scheduled at Day Friday Position 2.
# Section A successfully scheduled at Day Friday Position 2.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Yogita
# Class slot at Day Tuesday Position 5 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Yogita
# Class Discrete Mathematics successfully scheduled at Day Tuesday Position 1.
# Section B successfully scheduled at Day Tuesday Position 1.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Yogita
# Class slot at Day Thursday Position 5 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Yogita
# Class slot at Day Thursday Position 2 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Yogita
# Class slot at Day Thursday Position 5 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Yogita
# Class slot at Day Thursday Position 5 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Yogita
# Class slot at Day Thursday Position 5 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Yogita
# Class slot at Day Thursday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Yogita
# Class slot at Day Thursday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Yogita
# Class Discrete Mathematics successfully scheduled at Day Thursday Position 1.
# Section B successfully scheduled at Day Thursday Position 1.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Neha
# Class Discrete Mathematics successfully scheduled at Day Thursday Position 1.
# Section C successfully scheduled at Day Thursday Position 1.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Neha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Neha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Neha
# Class slot at Day Wednesday Position 5 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Neha
# Class Discrete Mathematics successfully scheduled at Day Wednesday Position 0.
# Section C successfully scheduled at Day Wednesday Position 0.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Neha
# Class Discrete Mathematics successfully scheduled at Day Monday Position 1.
# Section D successfully scheduled at Day Monday Position 1.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Neha
# Class Discrete Mathematics successfully scheduled at Day Tuesday Position 3.
# Section D successfully scheduled at Day Tuesday Position 3.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Rajni
# Class slot at Day Thursday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Rajni
# Class Discrete Mathematics successfully scheduled at Day Thursday Position 3.
# Section E successfully scheduled at Day Thursday Position 3.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Rajni
# Class Discrete Mathematics successfully scheduled at Day Monday Position 2.
# Section E successfully scheduled at Day Monday Position 2.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Pooja
# Class Digital Electronics successfully scheduled at Day Tuesday Position 4.
# Section A successfully scheduled at Day Tuesday Position 4.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Pooja
# Class Digital Electronics successfully scheduled at Day Friday Position 5.
# Section A successfully scheduled at Day Friday Position 5.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Arjun
# Class slot at Day Friday Position 5 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Arjun
# Class Digital Electronics successfully scheduled at Day Friday Position 1.
# Section B successfully scheduled at Day Friday Position 1.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Arjun
# Class slot at Day Thursday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Arjun
# Class slot at Day Thursday Position 1 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Arjun
# Class Digital Electronics successfully scheduled at Day Thursday Position 5.
# Section B successfully scheduled at Day Thursday Position 5.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Sharda
# Class Digital Electronics successfully scheduled at Day Monday Position 5.
# Section C successfully scheduled at Day Monday Position 5.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Sharda
# Class slot at Day Friday Position 2 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Sharda
# Class Digital Electronics successfully scheduled at Day Friday Position 5.
# Section C successfully scheduled at Day Friday Position 5.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Anjali
# Class Digital Electronics successfully scheduled at Day Wednesday Position 4.
# Section D successfully scheduled at Day Wednesday Position 4.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Anjali
# Class Digital Electronics successfully scheduled at Day Thursday Position 4.
# Section D successfully scheduled at Day Thursday Position 4.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Vandana
# Class Digital Electronics successfully scheduled at Day Thursday Position 2.
# Section E successfully scheduled at Day Thursday Position 2.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Vandana
# Class slot at Day Tuesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Vandana
# Class Digital Electronics successfully scheduled at Day Tuesday Position 4.
# Section E successfully scheduled at Day Tuesday Position 4.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
for sec in section_list:
    print('Section',sec.section_name)
    display_timetable(sec)
    print('----'*20)
# Out:
# Section A
# Monday : [102, 0, 0, 0, 0, 0]
# Tuesday : [0, 103, 101, 0, 104, 0]
# Wednesday : [0, 101, 101, 0, 102, 102]
# Thursday : [0, 102, 0, 104, 104, 101]
# Friday : [101, 0, 103, 102, 0, 104]
# --------------------------------------------------------------------------------
# Section B
# Monday : [0, 0, 101, 101, 104, 104]
# Tuesday : [0, 103, 0, 102, 0, 0]
# Wednesday : [0, 102, 0, 101, 0, 0]
# Thursday : [102, 103, 101, 0, 0, 104]
# Friday : [101, 104, 0, 0, 102, 102]
# --------------------------------------------------------------------------------
# Section C
# Monday : [0, 0, 0, 0, 102, 104]
# Tuesday : [0, 0, 104, 104, 101, 101]
# Wednesday : [103, 0, 0, 102, 102, 101]
# Thursday : [101, 103, 102, 0, 0, 0]
# Friday : [0, 101, 102, 0, 0, 104]
# --------------------------------------------------------------------------------
# Section D
# Monday : [102, 103, 0, 0, 104, 104]
# Tuesday : [102, 0, 0, 103, 0, 101]
# Wednesday : [101, 101, 0, 0, 104, 0]
# Thursday : [0, 0, 101, 0, 104, 102]
# Friday : [0, 101, 102, 102, 0, 0]
# --------------------------------------------------------------------------------
# Section E
# Monday : [104, 104, 103, 102, 101, 101]
# Tuesday : [0, 101, 102, 102, 104, 0]
# Wednesday : [0, 0, 0, 102, 0, 0]
# Thursday : [102, 101, 104, 103, 0, 0]
# Friday : [101, 0, 0, 0, 0, 0]
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Major lecture classes course fill up

# %%
for sec in section_list:
    major = get_major(sec)
    rand_day = random.sample(days, major.course_lectures) # random day from Monday to Friday
    for d in rand_day:
        slot = random.randint(1, 6) #  random slot from 1 to 6
        single_insert_check(section=sec, day=d, position=slot, course=major)
# Out:
# FACULTY: Akanksha
# Class PFDS successfully scheduled at Day Monday Position 2.
# Section A successfully scheduled at Day Monday Position 2.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Akanksha
# Class PFDS successfully scheduled at Day Thursday Position 0.
# Section A successfully scheduled at Day Thursday Position 0.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Akanksha
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Akanksha
# Class PFDS successfully scheduled at Day Wednesday Position 3.
# Section A successfully scheduled at Day Wednesday Position 3.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Prerna
# Class PFDS successfully scheduled at Day Wednesday Position 0.
# Section B successfully scheduled at Day Wednesday Position 0.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Prerna
# Class slot at Day Tuesday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Prerna
# Class PFDS successfully scheduled at Day Tuesday Position 0.
# Section B successfully scheduled at Day Tuesday Position 0.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Prerna
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Prerna
# Class PFDS successfully scheduled at Day Monday Position 1.
# Section B successfully scheduled at Day Monday Position 1.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Nisha
# Class slot at Day Friday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Nisha
# Class GDAC successfully scheduled at Day Friday Position 0.
# Section C successfully scheduled at Day Friday Position 0.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Nisha
# Class GDAC successfully scheduled at Day Monday Position 1.
# Section C successfully scheduled at Day Monday Position 1.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Nisha
# Class GDAC successfully scheduled at Day Thursday Position 3.
# Section C successfully scheduled at Day Thursday Position 3.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Pankaj
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Pankaj
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Pankaj
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Pankaj
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Pankaj
# Class EWA successfully scheduled at Day Monday Position 3.
# Section D successfully scheduled at Day Monday Position 3.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Pankaj
# Class EWA successfully scheduled at Day Tuesday Position 1.
# Section D successfully scheduled at Day Tuesday Position 1.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Pankaj
# Class slot at Day Wednesday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Pankaj
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Pankaj
# Class slot at Day Wednesday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Pankaj
# Class slot at Day Wednesday Position 4 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Pankaj
# Class EWA successfully scheduled at Day Wednesday Position 5.
# Section D successfully scheduled at Day Wednesday Position 5.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Shaveta
# Class slot at Day Tuesday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Tuesday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Tuesday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Tuesday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Tuesday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Tuesday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Tuesday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Tuesday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Tuesday Position 3 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class EWA successfully scheduled at Day Tuesday Position 5.
# Section E successfully scheduled at Day Tuesday Position 5.
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# ...
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 1
# FACULTY: Shaveta
# Class slot at Day Monday Position 0 is occupied. Finding a new position.
# Trying a new position: 5
# FACULTY: Shaveta
# Class slot at Day Monday Position 4 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 6
# FACULTY: Shaveta
# Class slot at Day Monday Position 5 is occupied. Finding a new position.
# Trying a new position: 2
# FACULTY: Shaveta
# Class slot at Day Monday Position 1 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 3
# FACULTY: Shaveta
# Class slot at Day Monday Position 2 is occupied. Finding a new position.
# Trying a new position: 4
# FACULTY: Shaveta
# Class slot at Day Monday Position 3 is occupied. Finding a new position.
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[10], line 6
#       4 for d in rand_day:
#       5     slot = random.randint(1, 6) #  random slot from 1 to 6
# ----> 6     single_insert_check(section=sec, day=d, position=slot, course=major)
#
# Cell In[2], line 42, in single_insert_check(section, day, position, course)
#      40 new_position = random.randint(1, 6)
#      41 print(f"Trying a new position: {new_position}")
# ---> 42 single_insert_check(section, day, new_position, course)
#
# Cell In[2], line 42, in single_insert_check(section, day, position, course)
#      40 new_position = random.randint(1, 6)
#      41 print(f"Trying a new position: {new_position}")
# ---> 42 single_insert_check(section, day, new_position, course)
#
#     [... skipping similar frames: single_insert_check at line 42 (11967 times)]
#
# Cell In[2], line 42, in single_insert_check(section, day, position, course)
#      40 new_position = random.randint(1, 6)
#      41 print(f"Trying a new position: {new_position}")
# ---> 42 single_insert_check(section, day, new_position, course)
#
# Cell In[2], line 40, in single_insert_check(section, day, position, course)
#      37 else:
#      38     # case of clash
#      39     print(f"Class slot at Day {day} Position {position} is occupied. Finding a new position.")
# ---> 40     new_position = random.randint(1, 6)
#      41     print(f"Trying a new position: {new_position}")
#      42     single_insert_check(section, day, new_position, course)
#
# File ~\anaconda3\Lib\random.py:362, in Random.randint(self, a, b)
#     358 def randint(self, a, b):
#     359     """Return random integer in range [a, b], including both end points.
#     360     """
# --> 362     return self.randrange(a, b+1)
#
# File ~\anaconda3\Lib\random.py:344, in Random.randrange(self, start, stop, step)
#     342 if istep == 1:
#     343     if width > 0:
# --> 344         return istart + self._randbelow(width)
#     345     raise ValueError("empty range for randrange() (%d, %d, %d)" % (istart, istop, width))
#     347 # Non-unit step argument supplied.
#
# File ~\anaconda3\Lib\random.py:239, in Random._randbelow_with_getrandbits(self, n)
#     236 "Return a random int in the range [0,n).  Defined for n > 0."
#     238 getrandbits = self.getrandbits
# --> 239 k = n.bit_length()  # don't use (n-1) here because n can be 1
#     240 r = getrandbits(k)  # 0 <= r < 2**k
#     241 while r >= n:
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
for sec in section_list:
    print('Section',sec.section_name)
    display_timetable(sec)
    print('----'*20)
# Out:
# Section A
# Monday : [102, 0, 201, 0, 0, 0]
# Tuesday : [0, 103, 101, 0, 104, 0]
# Wednesday : [0, 101, 101, 201, 102, 102]
# Thursday : [201, 102, 0, 104, 104, 101]
# Friday : [101, 0, 103, 102, 0, 104]
# --------------------------------------------------------------------------------
# Section B
# Monday : [0, 201, 101, 101, 104, 104]
# Tuesday : [201, 103, 0, 102, 0, 0]
# Wednesday : [201, 102, 0, 101, 0, 0]
# Thursday : [102, 103, 101, 0, 0, 104]
# Friday : [101, 104, 0, 0, 102, 102]
# --------------------------------------------------------------------------------
# Section C
# Monday : [0, 202, 0, 0, 102, 104]
# Tuesday : [0, 0, 104, 104, 101, 101]
# Wednesday : [103, 0, 0, 102, 102, 101]
# Thursday : [101, 103, 102, 202, 0, 0]
# Friday : [202, 101, 102, 0, 0, 104]
# --------------------------------------------------------------------------------
# Section D
# Monday : [102, 103, 0, 203, 104, 104]
# Tuesday : [102, 203, 0, 103, 0, 101]
# Wednesday : [101, 101, 0, 0, 104, 203]
# Thursday : [0, 0, 101, 0, 104, 102]
# Friday : [0, 101, 102, 102, 0, 0]
# --------------------------------------------------------------------------------
# Section E
# Monday : [104, 104, 103, 102, 101, 101]
# Tuesday : [0, 101, 102, 102, 104, 203]
# Wednesday : [0, 0, 0, 102, 0, 0]
# Thursday : [102, 101, 104, 103, 0, 0]
# Friday : [101, 0, 0, 0, 0, 0]
# --------------------------------------------------------------------------------

# %%
import pandas as pd

# %%
import os
section_timetable = os.path.join('timetables', 'sections')
faculty_timetable = os.path.join('timetables', 'faculty')

try:
    os.makedirs(section_timetable)
    os.makedirs(faculty_timetable)
    print(f"Directory '{section_timetable}' created successfully.")
    print(f"Directory '{faculty_timetable}' created successfully.")
except FileExistsError:
    print(f"Directory '{section_timetable}' already exists.")
    print(f"Directory '{faculty_timetable}' already exists.")
# Out:
# Directory 'timetables\sections' already exists.
# Directory 'timetables\faculty' already exists.

# %%
## Storing section timetables into files

# %%
for sec in section_list:
    df = pd.DataFrame(sec.timetable).T
    name = sec.section_name + '.csv'
    path = os.path.join(section_timetable,name)
    df.to_csv(path,index=True)

# %%
for faculty in faculty_list:
    df = pd.DataFrame(faculty.timetable).T
    name = faculty.faculty_name + '.csv'
    path = os.path.join(faculty_timetable,name)
    df.to_csv(path,index=True)
